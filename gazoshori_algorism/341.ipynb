# %%
# p115
import cv2
import numpy as np
from matplotlib import pyplot as plt

def main():
    img = cv2.imread("./sample/3-4/input.jpg")
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    hist, bins = np.histogram(gray.ravel(), 256 , [0,256])
    print(hist)

    plt.xlim(0,255)
    plt.plot(hist)
    plt.grid()
    plt.show()
    

main()
# Out:
# [  57   33   41   24   33   29   31   23   21   28   32   46   41   38
#    43   42   55   50   59   46   48   54   54   48   54   52   60   53
#    55   56   56   48   53   56   57   60   69   52   63   62   76   64
#    69   46   65   65   68   57   43   63   47   63   67   53   53   70
#    75   71   74   96  111  128  185  158  152  166  187  155  178  215
#   231  216  251  283  215  228  210  200  156  152  137  129  110  116
#   104   77   98   74   85   80  102   70   72   80   64   70   75   71
#    68   79   78   62   64   68   72   65   63   76   82   67   74   64
#    43   44   45   51   57   73   68   56   47   67   60   51   50   48
#    64   65   81  102  127  235  311  517  752 1272 2344  813  525  307
#   250  242  175  136  124  116  100  107   94   83   67   60   42   45
#    44   27   28   25   33   23   34   39   34   26   23   23   37   29
#    43   38   51   81   71   97   87   77   97  101   96   89  106   79
# ...

# %% [markdown]
# # 3-4-2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def main():
    img = cv2.imread("sample/3-4/input.jpg")
    
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    a, k = 0.7, 20
    zmin , zmax = 20.0, 220.0
    
    gray = gray.astype(np.uint16)
#     gray = a * gray
    gray = gray + k*5
#     gray = a *(gray -127) + 127 # 変換3
    # gray = gray.max() * (gray-zmin) / (zmax - zmin)
#     print(type(gray))
    gray[gray < 0] = 0
    gray[gray > 255] = 255
    

    ####
    #表示部分
    # numpy 変換
    gray_int = gray.astype(np.uint8)
    im4p = cv2.cvtColor( gray_int, cv2.COLOR_BGR2RGB )
#     print(im4p)
    plt.imshow(im4p)
    
    
main()

# %% [markdown]
# ## 3-4-3

# %%
import cv2
import numpy as np

def main():
    img = cv2.imread("./sample/3-4/input.jpg")

    # グレースケール変換
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # 線形濃度変換
    gamma = 2.0
    
    imax = gray.max()
    
    # ガンマ補正
    gray = imax * (gray/imax)**(1/gamma)
    
    # 結果の出力
    gray_int = gray.astype(np.uint8)
    im4p = cv2.cvtColor( gray_int, cv2.COLOR_BGR2RGB )
    plt.imshow(im4p)
   
main()
