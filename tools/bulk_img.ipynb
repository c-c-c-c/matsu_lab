# %%
##画像の右と下に黒い部分を継ぎ足す

def bulk_img( img, bulk_h, bulk_w):

    h, w =  img.shape[0], img.shape[1]
    
    dst = None
    d = None
    if len(img) > 2:
        d = img.shape[2]
        dst = np.concatenate([img, np.zeros((bulk_h, w, d ))],axis = 0)
#         breakpoint()
        dst = np.concatenate([dst, np.zeros((h+bulk_h, bulk_w,d ))], axis = 1)
    else:
        dst = np.concatenate([img, np.zeros((bulk_h, w ))])
        dst = np.concatenate([dst, np.zeros((h+bulk_h, bulk_w ))], axis = 1)

    return (dst)

# %%
## 使い方サンプル

# 画像を読み込む
import urllib.request ;import cv2; import matplotlib.pyplot as plt; import numpy as np
img_url = 'https://www.rikkyo.ac.jp/qo9edr00000000db-img/qo9edr00000000it.jpg' # ここを好きに変える
img_rikkyo = cv2.imdecode(np.fromstring(urllib.request.urlopen(img_url).read(), np.uint8), cv2.IMREAD_COLOR)

################
# メイン：黒をたす
################
img_rikkyo = bulk_img(img_rikkyo, 100, 300)


## 表示確認
img_rikkyo = img_rikkyo.astype(np.uint8)
im4p = cv2.cvtColor(img_rikkyo, cv2.COLOR_BGR2RGB)
plt.imshow(im4p)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
